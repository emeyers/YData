# %% [raw]
# ---
# execute:
#   cache: false
# format:
#   pdf:
#     include-in-header:
#        text: |
#          \newcommand{\textasciicaret}{\^{}}
#          \usepackage{fvextra}
#          \DefineVerbatimEnvironment{Highlighting}{Verbatim}{breaklines,commandchars=\\\{\}}
#     include-before-body:
#         text: |
#          \RecustomVerbatimEnvironment{verbatim}{Verbatim}{showspaces = false, showtabs = false, breaksymbolleft={}, breaklines}
# ---

# %% [markdown]
# # Reviewer template
#
# This is a template for reviewing class projects. Please fill out the sections below to review a project. Once you have filled out your reviews, email your reviews **as a Jupyter notebook** to the authors, and submit your reviews **as a pdf** to Gradescope by **Sunday November 23rd**. Instructions for sending your reviews to the authors, and for submitting your reviews to Gradescope, are at the bottom of this document.
#
# Remeber, these reviews are not annoymous so be sure to be positive in your review, but also be critical in order to help make the author's project stronger for their final submission!
#
#
# #### Project writer name:
# #### Project writer email address:
#
# #### Reviewer name:
# #### Reviwer email address:

# %% [markdown]
# # Summary
#
# Please write a one paragraph (~3-6 sentence) summary of the project here. You should summarize the main goals and findings of the project.
#
#
#
# ## 1. Overall strengths and weaknesses
#
# Please write 1-2 paragraphs that describe overall what you think the strengths and weakness are of the project. In particular, mention what you found interesting about the results, which analyses/visualizations you found convincing, and what could be done to potentially make the project stronger.
#
#
#
# ## 2. Major revisions
#
# Add bullet points of items that you think should definitely be changed for the final submission of the project.
#
#
#
#
# ## 3. Minor revisions
#
#
# Add bullet points of items that are more minor, but that would be good to change for the final submission of the project.
#
#
#
#
#
# ## 3. Rubric score
#
# Please write a score for the project based on the project rubric that is on the top of the class Canvas page (where all the project related information is listed). For any items where there would be points deducted, please cut and paste a bullet point for that item in the "Items for points take off" section below.
#
#
#
#
# #### Rubric items where points would be taken off if not addressed:
#
# - Item 1
# - Item 2
# - ...
#
#
#
# ### Total score:   xx/90

# %% [markdown]
# # Notes on submiting your reviews
#
# Since you are reviewing three projects, we recommend renaming the `reviewer_template.ipynb` to the name of the student `student_name.ipynb` (e.g., if you were reviewing my project, you should name it `ethan_meyers.ipynb`). This will allow you to have three different files for the three students whose work you are reviewing.
#
# Once you have completed your reviews please submit them as follows:
#
# 1. Send each review **as a Jupyter notebook** to the student whose work you reviewed. This will allow them to cut and paste your review in the appendix of their project Jupyter notebook.
#
# 2. Combine all three reviews into a single Jupyter notebook (which you can call `combined_reviews_for_gradescope.ipynb`). Then convert this notebook into a **pdf** to submit to gradescope. You can convert the file to a pdf by running the command in the cell below.
#
# Also, when cutting and pasting your reviews into your own Jupyter notebook project, please omit including these instructions

# %%
# !quarto render combined_reviews_for_gradescope.ipynb --cache-refresh --to pdf
